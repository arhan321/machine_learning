# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = "/root/machine_learning/testing_jupyter/annual-enterprise-survey-2023-financial-year-provisional.csv" 
df = pd.read_csv(file_path)

# %%
# Buat figure dan axes
fig, ax = plt.subplots(figsize=(12, 6))

# Plot setiap kategori secara manual agar label dikenali
grouped_df.plot(kind="bar", ax=ax, color=["blue", "red"])

# Tambahkan legenda langsung dari axes
ax.legend(title="Kategori Keuangan")

# Tambahkan judul dan label
ax.set_title("Perbandingan Total Income vs Total Expenditure per Industri (2023)", fontsize=14)
ax.set_xlabel("Industri", fontsize=12)
ax.set_ylabel("Nilai (Juta Dolar)", fontsize=12)
plt.xticks(rotation=75)
ax.grid(axis="y", linestyle="--", alpha=0.7)

# Tampilkan grafik
plt.show()
